# %%
import pandas as pd
import pyarrow
import openpyxl

# %%
df1=pd.read_csv(r"C:\PythonWorkshop\wsbpythonfiles\Zadania\ZadaniaDf1.csv"
               ,sep="/"
               )
df2=pd.read_parquet(r"C:\PythonWorkshop\wsbpythonfiles\Zadania\ZadaniaDf2.parquet"
                   ,use_nullable_dtypes=True
                   ,engine="pyarrow")
df3=pd.read_csv(r"C:\PythonWorkshop\wsbpythonfiles\Zadania\ZadaniaDf3.txt"
               ,sep=" ")
df4=pd.read_excel(r"C:\PythonWorkshop\wsbpythonfiles\Zadania\ZadaniaDf4.xlsx")
# Out:
# C:\Users\sqladmin\AppData\Local\Temp\2\ipykernel_8024\962080886.py:4: FutureWarning: The argument 'use_nullable_dtypes' is deprecated and will be removed in a future version.Use dtype_backend='numpy_nullable' instead of use_nullable_dtype=True.
#   df2=pd.read_parquet(r"C:\PythonWorkshop\wsbpythonfiles\Zadania\ZadaniaDf2.parquet"

# %%
df4.head()
# Out:
#         City     Zone
# 0  Stockholm   Europe
# 1     Denver  America
# 2     Moscow     Asia
# 3  Marseille   Europe
# 4    Palermo   Europe

# %%
print(df1.info(show_counts=True))
print(df2.info(show_counts=True))
print(df3.info(show_counts=True))
print(df4.info(show_counts=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Invoice_Id       5000000 non-null  object
#  1   account_name     4772470 non-null  object
#  2   account_surname  4231219 non-null  object
#  3   age              5000000 non-null  int64
#  4   product          4443677 non-null  object
#  5   order_city       4688008 non-null  object
#  6   color            5000000 non-null  object
#  7   date             5000000 non-null  object
#  8   delivery_date    5000000 non-null  object
#  9   production_date  5000000 non-null  int64
# dtypes: int64(2), object(8)
# memory usage: 381.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
# ...

# %%
df1.head()
# Out:
#     Invoice_Id account_name account_surname  age product order_city   color  \
# 0  Invoice: 1A     Patricia    Old_Clifford   28     NaN  Stockholm   black
# 1  Invoice: 2A         John         Luciano   31  Prod C    Palermo  orange
# 2  Invoice: 3A    Elizabeth        Clifford   32     NaN    Nairobi  indigo
# 3  Invoice: 4A       Robert    Vallllentine   25  Prod D        NaN   green
# 4  Invoice: 5A     patricia          Peroni   47  Prod A  Marseille  orange
#
#          date delivery_date  production_date
# 0  2014-09-10    2014-09-25         20140908
# 1  2010-11-29    2010-11-30         20101125
# 2  2010-05-30    2010-06-09         20100529
# 3  2017-02-01    2017-02-05         20170129
# 4  2017-01-29    2017-02-13         20170127

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.duplicated(subset=["Invoice_Id","account_name","account_surname","age","order_city"]).sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# Invoice_Id              0
# account_name       227530
# account_surname    768781
# age                     0
# product            556323
# order_city         311992
# color                   0
# date                    0
# delivery_date           0
# production_date         0
# dtype: int64

# %%
df2.sample(5)
# Out:
#         account_name account_surname         Invoice_Id discount  ordered  \
# 3123787         MarY          Robust  Invoice: 3123788A      0.3       97
# 533391         james                   Invoice: 533392A      0.4       26
# 3108830       Robert                  Invoice: 3108831A                75
# 2556095      William        Clifford  Invoice: 2556096A      0.2       95
# 586149         Linda          Robust   Invoice: 586150A      0.2       28
#
#          quantity region additional_delivery_cost          wrh_city
# 3123787        95                              TC     Krakow_Manila
# 533391         17                               T     Warsaw_Madrid
# 3108830        61                              TC  Poznan_Milwaukee
# 2556095        76                              TC     Warsaw_Manila
# 586149         28                               T    Poznan_Palermo

# %%
df2.duplicated(subset="Invoice_Id").sum()
# Out:
# 0

# %%
df2.isnull().sum()
# Out:
# account_name                0
# account_surname             0
# Invoice_Id                  0
# discount                    0
# ordered                     0
# quantity                    0
# region                      0
# additional_delivery_cost    0
# wrh_city                    0
# dtype: int64

# %%
df3.sample(5)
# Out:
#                 Invoice_Id  discount  ordered  quantity  region  \
# 1177629  Invoice: 1177630A       0.1       35        28     NaN
# 1511205  Invoice: 1511206A       NaN       75        70     NaN
# 2879753  Invoice: 2879754A       0.2       73        59     NaN
# 1431420  Invoice: 1431421A       NaN       47        41     NaN
# 1276566  Invoice: 1276567A       0.3       29        15     NaN
#
#         additional_delivery_cost         wrh_city  price
# 1177629                        T      Poznan_Oslo      5
# 1511205                        T    Warsaw_Madrid      9
# 2879753                        T  Wroclaw_Palermo      7
# 1431420                        T    Warsaw_Lisbon      9
# 1276566                        T   Wroclaw_Madrid      9

# %%
df3.duplicated(subset="Invoice_Id").sum()
# Out:
# 0

# %%
df4.sample(5)
# Out:
#               City     Zone
# 8          Nairobi   Africa
# 9   Río de Janeiro  America
# 14       Milwaukee  America
# 2           Moscow     Asia
# 1           Denver  America

# %%
df4.duplicated().sum()
# Out:
# 0

# %%
df1.sample()
# Out:
#               Invoice_Id account_name account_surname  age product order_city  \
# 823425  Invoice: 823426A    Elizabeth         Hawkins   48  Prod D     Madrid
#
#        color        date delivery_date  production_date
# 823425   red  2011-02-02    2011-02-04         20110127

# %%
df2.sample()
# Out:
#         account_name account_surname         Invoice_Id discount  ordered  \
# 2884661     Jennifer          Robust  Invoice: 2884662A      0.2       43
#
#          quantity region additional_delivery_cost     wrh_city
# 2884661        42                               T  Poznan_Oslo

# %%
df2.columns
# Out:
# Index(['account_name', 'account_surname', 'Invoice_Id', 'discount', 'ordered',
#        'quantity', 'region', 'additional_delivery_cost', 'wrh_city'],
#       dtype='object')

# %%
u_df1_df2 = df1.merge(right=df2,how="outer",right_on="Invoice_Id",left_on="Invoice_Id")

# %%
#"Invoice_Id", "discount", "ordered" ,"quantity", "region", "additional_delivery_cost", "wrh_city"
u_df1_df2 = df1.merge(
    right=df2[["Invoice_Id", "discount", "ordered" ,"quantity", "region", "additional_delivery_cost", "wrh_city"]]
    ,how="outer",right_on="Invoice_Id",left_on="Invoice_Id")

# %%
df3.sample(5)
# Out:
#                 Invoice_Id  discount  ordered  quantity  region  \
# 4570351  Invoice: 4570352A       NaN       95        89     NaN
# 4717903  Invoice: 4717904A       NaN       11        -2     NaN
# 4905408  Invoice: 4905409A       0.1       50        42     NaN
# 103521    Invoice: 103522A       0.3       67        67     NaN
# 3014733  Invoice: 3014734A       0.4       14        14     NaN
#
#         additional_delivery_cost          wrh_city  price
# 4570351                        T     Krakow_Lisbon      9
# 4717903                        T     Poznan_Lisbon      9
# 4905408                        T  Poznan_Stockholm      9
# 103521                         T  Poznan_Marseille      5
# 3014733                        T      Wroclaw_Oslo      7

# %%
u_df1_df2.sample(5)
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 4661832  Invoice: 4661833A      Richard          Peroni  390  Prod D
# 2375175  Invoice: 2375176A        james             NaN   43  Prod H
# 725310    Invoice: 725311A    Elizabeth         Luciano   57  Prod G
# 3685201  Invoice: 3685202A      Michael        Clifford   58  Prod H
# 2595362  Invoice: 2595363A    Juan Luis         Luciano   27  Prod D
#
#         order_city   color        date delivery_date  production_date  \
# 4661832  Milwaukee   beige  2012-10-22    2012-11-02         20121014
# 2375175     Madrid  indigo  2010-06-29    2010-07-01         20100616
# 725310      Berlin  yellow  2018-01-26    2018-02-03         20180122
# 3685201       Oslo     red  2016-04-23    2016-05-06         20160420
# 2595362  Marseille    blue  2013-01-03    2013-01-11         20121231
#
#         discount  ordered  quantity region additional_delivery_cost  \
# ...

# %%
u_df1_2_3 = u_df1_df2.merge(right=df3,how="left",right_on="Invoice_Id",left_on="Invoice_Id")

# %%
u_df1_2_3.sample(5)
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 4089289  Invoice: 4089290A          NaN      Vallentine   64  Prod B
# 1025457  Invoice: 1025458A        Ahmed    Vallllentine   46  Prod D
# 3790641  Invoice: 3790642A     Patricia          Robust   52  Prod G
# 3655866  Invoice: 3655867A        James    Old_Clifford  530  Prod G
# 3299576  Invoice: 3299577A         MarY             NaN  450  Prod A
#
#         order_city   color        date delivery_date  production_date  ...  \
# 4089289      Tokyo  indigo  2010-03-09    2010-03-09         20100301  ...
# 1025457      Tokyo    pink  2015-08-08    2015-08-12         20150805  ...
# 3790641     Denver    gold  2013-12-02    2013-12-19         20131125  ...
# 3655866     Lisbon  orange  2011-06-22    2011-06-28         20110614  ...
# 3299576     Manila    grey  2015-02-26    2015-03-08         20150213  ...
#
#         region_x  additional_delivery_cost_x     wrh_city_x discount_y  \
# ...

# %%
u_df123 = u_df1_df2.merge(df3[["price","region"]],how="left",right_on="Invoice_Id",left_on="Invoice_Id")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\2\ipykernel_8024\539220734.py in ?()
# ----> 1 u_df123 = u_df1_df2.merge(df3[["price","region"]],how="left",right_on="Invoice_Id",left_on="Invoice_Id")
#
# C:\PythonWorkshop\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10483         validate: MergeValidate | None = None,
#   10484     ) -> DataFrame:
#   10485         from pandas.core.reshape.merge import merge
#   10486
# > 10487         return merge(
#   10488             self,
#   10489             right,
#   10490             how=how,
#
# C:\PythonWorkshop\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
u_df3 = df3[["Invoice_Id","price"]]

# %%
u_df3.sample(5)
# Out:
#                 Invoice_Id  price
# 1612        Invoice: 1613A      9
# 208007    Invoice: 208008A      9
# 2423790  Invoice: 2423791A      9
# 3514276  Invoice: 3514277A      7
# 4500338  Invoice: 4500339A      9

# %%
u_df123 = u_df1_df2.merge(right=u_df3,how="left",right_on="Invoice_Id",left_on="Invoice_Id")

# %%
u_df123.sample(5)
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 3073168  Invoice: 3073169A       RobeRT          Robust   43  Prod F
# 2473851  Invoice: 2473852A      Barbara         Luciano  440  Prod E
# 569225    Invoice: 569226A      Barbara            Nici   60  Prod C
# 1030101  Invoice: 1030102A          NaN          Peroni   30  Prod F
# 4898672  Invoice: 4898673A        James    Old_Clifford   63     NaN
#
#              order_city   color        date delivery_date  production_date  \
# 3073168          Moscow   brown  2017-07-04    2017-07-11         20170629
# 2473851       Marseille  silver  2014-03-22    2014-04-11         20140321
# 569225           Lisbon   black  2016-11-18    2016-12-08         20161111
# 1030101          Moscow  indigo  2010-10-17    2010-10-29         20101012
# 4898672  Río de Janeiro   beige  2014-12-29    2014-12-29         20141220
#
#         discount  ordered  quantity region additional_delivery_cost  \
# ...

# %%
df4
# Out:
#               City     Zone
# 0        Stockholm   Europe
# 1           Denver  America
# 2           Moscow     Asia
# 3        Marseille   Europe
# 4          Palermo   Europe
# 5            Tokyo     Asia
# 6           Lisbon   Europe
# 7             Oslo   Europe
# 8          Nairobi   Africa
# 9   Río de Janeiro  America
# 10          Berlin   Europe
# 11          Bogotá  America
# 12          Manila     Asia
# 13          Madrid   Europe
# 14       Milwaukee  America

# %%
u_df1234=u_df123.merge(right=df4,how="left",left_on="order_city",right_on="City")

# %%
u_df1234.sample(5)
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 4025639  Invoice: 4025640A         JohN    Vallllentine   46     NaN
# 4163946  Invoice: 4163947A      Salomon         Luciano  380  Prod C
# 4774814  Invoice: 4774815A      Barbara         Hawkins   45  Prod D
# 4704850  Invoice: 4704851A    Juan Luis          Robust  480  Prod D
# 4682800  Invoice: 4682801A         MarY             NaN   55  Prod H
#
#         order_city   color        date delivery_date  production_date  \
# 4025639     Moscow   beige  2017-04-10    2017-04-29         20170402
# 4163946     Denver  silver  2017-01-21    2017-02-09         20170113
# 4774814        NaN     red  2014-09-27    2014-09-29         20140919
# 4704850     Moscow   green  2012-08-11    2012-08-29         20120804
# 4682800     Manila    blue  2010-09-28    2010-10-01         20100920
#
#         discount  ordered  quantity region additional_delivery_cost  \
# ...

# %%
merge_df = u_df1234.drop(columns=["City"])

# %%
merge_df.sample(5)
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 2102241  Invoice: 2102242A         Mary             NaN   57  Prod G
# 369033    Invoice: 369034A     Jennifer         Luciano   54  Prod B
# 4942709  Invoice: 4942710A         JohN           Ellen   58     NaN
# 1747963  Invoice: 1747964A      Richard         Luciano   36  Prod E
# 2895638  Invoice: 2895639A        Susan    Vallllentine   44  Prod E
#
#         order_city   color        date delivery_date  production_date  \
# 2102241     Lisbon   black  2014-06-22    2014-07-11         20140615
# 369033        Oslo    grey  2013-05-02    2013-05-15         20130426
# 4942709     Lisbon    gold  2011-04-22    2011-05-04         20110419
# 1747963    Nairobi   green  2012-01-02    2012-01-15         20111229
# 2895638  Milwaukee  silver  2016-09-06    2016-09-24         20160903
#
#         discount  ordered  quantity region additional_delivery_cost  \
# ...

# %%
merge_df.to_csv(path_or_buf=r"C:\PythonWorkshop\wsbpythonfiles\Zajecia\merge_df.csv"
           ,mode="w"
           ,index=True
           ,sep="|")

# %%
merge_df = pd.read_csv(r"C:\PythonWorkshop\wsbpythonfiles\Zajecia\merge_df.csv",sep="|", index_col=0)

# %%
merge_df.sample(5)
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 4476554  Invoice: 4476555A        Ahmed             NaN   28  Prod H
# 4178389  Invoice: 4178390A     patricia          Robust   34  Prod G
# 171254    Invoice: 171255A      Barbara             NaN   41  Prod C
# 1281467  Invoice: 1281468A    Juan Luis      Vallentine   39  Prod A
# 2217075  Invoice: 2217076A       Robert    Vallllentine   31  Prod G
#
#         order_city   color        date delivery_date  production_date  \
# 4476554        NaN   green  2013-12-18    2014-01-07         20131212
# 4178389      Tokyo    pink  2014-05-31    2014-06-19         20140520
# 171254      Berlin  silver  2012-03-06    2012-03-18         20120302
# 1281467    Nairobi   white  2010-01-25    2010-01-31         20100112
# 2217075     Bogotá   black  2014-02-02    2014-02-02         20140131
#
#          discount  ordered  quantity  region additional_delivery_cost  \
# ...

# %%
merge_df.duplicated(subset=["Invoice_Id"],keep=False).sum()
# Out:
# 0

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000000 entries, 0 to 4999999
# Data columns (total 18 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Invoice_Id                object
#  1   account_name              object
#  2   account_surname           object
#  3   age                       int64
#  4   product                   object
#  5   order_city                object
#  6   color                     object
#  7   date                      object
#  8   delivery_date             object
#  9   production_date           int64
#  10  discount                  float64
#  11  ordered                   int64
#  12  quantity                  int64
#  13  region                    float64
#  14  additional_delivery_cost  object
#  15  wrh_city                  object
#  16  price                     int64
#  17  Zone                      object
# dtypes: float64(2), int64(5), object(11)
# memory usage: 724.8+ MB

# %%
merge_df.dropna(subset=["product"],how="all",inplace=True)

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4443677 entries, 1 to 4999999
# Data columns (total 18 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Invoice_Id                object
#  1   account_name              object
#  2   account_surname           object
#  3   age                       int64
#  4   product                   object
#  5   order_city                object
#  6   color                     object
#  7   date                      object
#  8   delivery_date             object
#  9   production_date           int64
#  10  discount                  float64
#  11  ordered                   int64
#  12  quantity                  int64
#  13  region                    float64
#  14  additional_delivery_cost  object
#  15  wrh_city                  object
#  16  price                     int64
#  17  Zone                      object
# dtypes: float64(2), int64(5), object(11)
# memory usage: 644.1+ MB

# %%
merge_df.query("`quantity`<=0")
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 33            Invoice: 34A      Michael             NaN  340  Prod E
# 62            Invoice: 63A      Salomon        Clifford   47  Prod F
# 139          Invoice: 140A         JohN           Ellen   36  Prod G
# 188          Invoice: 189A        James          Peroni  550  Prod G
# 330          Invoice: 331A     Jennifer          Peroni   62  Prod C
# ...                    ...          ...             ...  ...     ...
# 4999757  Invoice: 4999758A        Linda         Hawkins   42  Prod C
# 4999896  Invoice: 4999897A     patricia      Vallentine   54  Prod C
# 4999916  Invoice: 4999917A        Susan    Old_Clifford  310  Prod H
# 4999960  Invoice: 4999961A      Salomon          Robust   41  Prod G
# 4999971  Invoice: 4999972A    Juan Luis          Robust   40  Prod E
#
#         order_city   color        date delivery_date  production_date  \
# ...

# %%
ujemne = merge_df[(merge_df["quantity"]<=0)].index

# %%
ujemne
# Out:
# Index([     33,      62,     139,     188,     330,     357,     401,     405,
#            425,     442,
#        ...
#        4999663, 4999691, 4999694, 4999705, 4999714, 4999757, 4999896, 4999916,
#        4999960, 4999971],
#       dtype='int64', length=135805)

# %%
merge_df['ujemne'] = merge_df['quantity']>=0

# %%
merge_df = merge_df.rename(columns={'ujemne':'dodatnie'})

# %%
merge_df.sample(5)
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 600744    Invoice: 600745A        Susan      Old_Robust  350  Prod G
# 1827688  Invoice: 1827689A      Barbara         Luciano   27  Prod F
# 3161687  Invoice: 3161688A      Barbara           Ellen   41  Prod F
# 3595807  Invoice: 3595808A         JohN           Ellen   47  Prod F
# 1282159  Invoice: 1282160A       Robert          Peroni   26  Prod C
#
#         order_city  color        date delivery_date  production_date  \
# 600744      Berlin   pink  2010-02-19    2010-03-11         20100217
# 1827688    Nairobi   gold  2017-12-25    2018-01-10         20171213
# 3161687     Berlin   gold  2011-05-22    2011-06-07         20110509
# 3595807     Madrid  black  2013-12-15    2013-12-29         20131208
# 1282159     Moscow  white  2011-06-22    2011-07-05         20110618
#
#          discount  ordered  quantity  region additional_delivery_cost  \
# ...

# %%
merge_72 = merge_df[merge_df['dodatnie']==True]

# %%
merge_72.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4307872 entries, 1 to 4999999
# Data columns (total 19 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Invoice_Id                object
#  1   account_name              object
#  2   account_surname           object
#  3   age                       int64
#  4   product                   object
#  5   order_city                object
#  6   color                     object
#  7   date                      object
#  8   delivery_date             object
#  9   production_date           int64
#  10  discount                  float64
#  11  ordered                   int64
#  12  quantity                  int64
#  13  region                    float64
#  14  additional_delivery_cost  object
#  15  wrh_city                  object
#  16  price                     int64
#  17  Zone                      object
#  18  dodatnie                  bool
# dtypes: bool(1), float64(2), int64(5), object(11)
# ...

# %%
merge_72.query("`quantity`<=0")
# Out:
# Empty DataFrame
# Columns: [Invoice_Id, account_name, account_surname, age, product, order_city, color, date, delivery_date, production_date, discount, ordered, quantity, region, additional_delivery_cost, wrh_city, price, Zone, dodatnie]
# Index: []

# %%
merge_72 = merge_72[merge_72['quantity']!=0]

# %%
merge_72.drop(columns=['dodatnie'])
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 1              Invoice: 2A         John         Luciano   31  Prod C
# 3              Invoice: 4A       Robert    Vallllentine   25  Prod D
# 4              Invoice: 5A     patricia          Peroni   47  Prod A
# 5              Invoice: 6A        Ahmed      Old_Robust   63  Prod A
# 6              Invoice: 7A      Salomon      Old_Robust   28  Prod E
# ...                    ...          ...             ...  ...     ...
# 4999995  Invoice: 4999996A      Michael            Nici   56  Prod A
# 4999996  Invoice: 4999997A      Richard      Vallentine   55  Prod G
# 4999997  Invoice: 4999998A         MarY         Luciano   43  Prod H
# 4999998  Invoice: 4999999A       RobeRT             NaN   27  Prod G
# 4999999  Invoice: 5000000A     Jennifer         Hawkins   29  Prod A
#
#         order_city   color        date delivery_date  production_date  \
# ...

# %%
merge_72.to_csv(path_or_buf=r"C:\PythonWorkshop\wsbpythonfiles\Zajecia\merge_8_4.csv"
           ,mode="w"
           ,index=True
           ,sep="|")

# %%
merge_72 = pd.read_csv(r"C:\PythonWorkshop\wsbpythonfiles\Zajecia\merge_7ok.csv",sep="|", index_col=0)

# %%
merge_72.sample(5)
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 803728    Invoice: 803729A    Elizabeth      Old_Robust   59  Prod F
# 643114    Invoice: 643115A        james    Vallllentine   31  Prod D
# 1870422  Invoice: 1870423A          NaN             NaN  430  Prod E
# 2606441  Invoice: 2606442A     patricia    Vallllentine   46  Prod G
# 4529542  Invoice: 4529543A        james         Luciano   43  Prod A
#
#         order_city   color        date delivery_date  production_date  \
# 803728   Marseille    gold  2015-02-05    2015-02-25         20150201
# 643114   Milwaukee    blue  2011-05-07    2011-05-07         20110429
# 1870422  Milwaukee    grey  2015-03-11    2015-03-15         20150304
# 2606441     Bogotá  yellow  2017-02-26    2017-03-11         20170214
# 4529542  Milwaukee    blue  2011-07-07    2011-07-17         20110706
#
#          discount  ordered  quantity  region additional_delivery_cost  \
# ...

# %%
merge_72.fillna(value={"accound_name":"John"},inplace=True)

# %%
merge_72.fillna(value={"accound_surname":"Doe"},inplace=True)

# %%
merge_72.fillna(value={"discount":"0.0"},inplace=True)

# %%
merge_72.drop(columns=['dodatnie','region'])
# Out:
#                 Invoice_Id account_name account_surname  age product  \
# 1              Invoice: 2A         John         Luciano   31  Prod C
# 3              Invoice: 4A       Robert    Vallllentine   25  Prod D
# 4              Invoice: 5A     patricia          Peroni   47  Prod A
# 5              Invoice: 6A        Ahmed      Old_Robust   63  Prod A
# 6              Invoice: 7A      Salomon      Old_Robust   28  Prod E
# ...                    ...          ...             ...  ...     ...
# 4999995  Invoice: 4999996A      Michael            Nici   56  Prod A
# 4999996  Invoice: 4999997A      Richard      Vallentine   55  Prod G
# 4999997  Invoice: 4999998A         MarY         Luciano   43  Prod H
# 4999998  Invoice: 4999999A       RobeRT             NaN   27  Prod G
# 4999999  Invoice: 5000000A     Jennifer         Hawkins   29  Prod A
#
#         order_city   color        date delivery_date  production_date  \
# ...

# %%
merge_72['order_city'].value_counts()
# Out:
# order_city
# Manila            538806
# Lisbon            270009
# Tokyo             269890
# Milwaukee         269580
# Marseille         269501
# Madrid            269428
# Río de Janeiro    269426
# Berlin            269399
# Denver            269282
# Palermo           269198
# Moscow            269149
# Oslo              268758
# Bogotá            268658
# Nairobi           268468
# Stockholm         268320
# Name: count, dtype: int64

# %%
merge_72.fillna(value={"order_city":"Manila"},inplace=True)

# %%
merge_72["order_city"]=="Malina"
# Out:
# 1          False
# 3           True
# 4          False
# 5          False
# 6          False
#            ...
# 4999995    False
# 4999996    False
# 4999997    False
# 4999998    False
# 4999999    False
# Name: order_city, Length: 4307872, dtype: bool
